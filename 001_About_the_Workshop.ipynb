# %% [markdown]
# ![Workshop Logo.png](data:image/png;base64,...)

# %% [markdown]
# # About the workshop
#
# ---

# %% [markdown]
# Part 1: Basics
# * Introduction
# * Coding best practices
# * Accessing & Plotting the data
#
# Part 2: Data Handling & Viasualization
# * Where does the data come from?
# * What does the data format look like?
# * How do we load it?
# * How to we visualize it?
#
# Part 3: Machine learning
# * Integrating loaded data: Seismic Well Tie
# * ML use case: Prediction of Well logs
#
# Part 4: Building a web application for machine learning
# * Basics
# * Introuction to Dash
# * ML app in Dash
# * Seismic data viz in Dash with interactive zoom
#
# We shall go into the background about some of these topics before diving deeper into coding them up.
#
# You shall have the chance to get your hands dirty soon!

# %% [markdown]
# ![ ](data:image/jpeg;base64,...)

# %% [markdown]
# -----

# %% [markdown]
# # What resources will we need?
#
# * In order to be able to have the best experience, we would recommend that you code along with us. We shall provide sample data.<br>
# * If you have Jupyter Notebook or Jupyter Lab in your computer already, you can run it locally.<br>
# * Otherwise, you will need a Google account to be able to use Colab effectively. If you don't already have one, now is a good time to create one.<br><br>

# %%
# Clone the git repo

# %%
##### Applicable only if you are running this notebook on Colab. Disble otherwise.
##### Mount your google drive to this notebook. It will require some permissions.

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# [Data](https://drive.google.com/drive/folders/16rCYKklQs-Jt5iVp1Gvfiu25ATz-BQ2D?usp=sharing)
