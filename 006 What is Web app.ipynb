# %% [markdown]
# ![Workshop Logo.png](data:image/png;base64,...)

# %% [markdown]
# # Web App basics

# %% [markdown]
# ## Typical Web application architecture
#
# ![How-does-Web-App-Architecture-Work-1024x450.png](data:image/png;base64,...)

# %% [markdown]
# **A web server** is software and hardware that uses HTTP (Hypertext Transfer Protocol) and other protocols to respond to client requests made over the World Wide Web. The main job of a web server is to display website content through storing, processing and delivering webpages to users.
#
# *   [Flask](https://flask.palletsprojects.com/en/2.2.x/)
# *   [FastAPI](https://fastapi.tiangolo.com/)
# *   [Django](https://www.djangoproject.com/)
# *   [NodeJs](https://nodejs.org/en)
#
# ![what_is_rest_api.png](data:image/png;base64,...)

# %% [markdown]
# ## Client Side Applications
# On every request complete HTML and data is sent by the server.
#
# ![server-side-rendering.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# ## Single page applications
#
# A single page application is a website or web application that dynamically rewrites a current web page with new data from the web server, instead of the default method of a web browser loading entire new pages.
#
# ![client-side-rendering.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# ## Building Web apps as a data scientist
#
#
#
# *   Useful when you want to build interactive dashboards
# *   Perform analysis that needs to be repeated over and over again
# *   Share results and analysis with others
# *   Shine in front of your boss
#
#
# There are three options out there:
#
#
#
# *   [Dash](https://plotly.com/dash/?gclid=Cj0KCQjww4-hBhCtARIsAC9gR3apZU50ZL1Y_V5km90LZoM4hAWoPjcK2RjQ3KYxmjvs4p3VHZiW5HAaAp3oEALw_wcB)
# *   [Streamlit](https://streamlit.io/)
# *   [Bokeh](https://bokeh.org/)

# %% [markdown]
# ## Deploying a Web app
#
# How ddo others users access it?
#
#
# *   [jupyter_dash](https://github.com/plotly/jupyter-dash)
# *   [Heroku](https://www.heroku.com/)
# *   [ngrok](https://ngrok.com/)
# *   you own commputer
# *   Big cloud providers: Azure, GCP, Amazon...
